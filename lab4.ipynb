# %% [markdown]
# # <center> Практические задания по цифровой обработке сигналов </center>
# # <center> Четвертая лабораторная работа </center>
# # <center> Акустические признаки </center>

# %%
import librosa
import numpy as np
import scipy 
import scipy.fft
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display
import librosa.filters
import hashlib
from glob import glob
import os
import sklearn
from utils.vscode.vscode_audio import Audio

# %matplotlib inline

# %%
# Функция отрисовки аудио сигнала. 
def draw_waveform(wav, sr, figsize=(14, 5)):
    # Отрисовка звукового сигнала во временной области
    plt.figure(figsize=figsize)
    librosa.display.waveplot(wav, sr=sr)
    plt.show()

# %%
# Для выполнения задания нам понадобится датасет yes/no. 
# Про датасет можно почитать тут https://www.openslr.org/1/

# Скачаем его
![ ! -f  waves_yesno.tar.gz ] && wget https://www.openslr.org/resources/1/waves_yesno.tar.gz
# И распакуем
# !tar -xvzf waves_yesno.tar.gz

# P.S если у вас Windows, или по каким-либо еще причинам данные не скачались, 
# то их можно скачать руками отсюда: https://www.openslr.org/1/
# Out:
# waves_yesno/
# waves_yesno/1_0_0_0_0_0_1_1.wav
# waves_yesno/1_1_0_0_1_0_1_0.wav
# waves_yesno/1_0_1_1_1_1_0_1.wav
# waves_yesno/1_1_1_1_0_1_0_0.wav
# waves_yesno/0_0_1_1_1_0_0_0.wav
# waves_yesno/0_1_1_1_1_1_1_1.wav
# waves_yesno/0_1_0_1_1_1_0_0.wav
# waves_yesno/1_0_1_1_1_0_1_0.wav
# waves_yesno/1_0_0_1_0_1_1_1.wav
# waves_yesno/0_0_1_0_1_0_0_0.wav
# waves_yesno/0_1_0_1_1_0_1_0.wav
# waves_yesno/0_0_1_1_0_1_1_0.wav
# waves_yesno/1_0_0_0_1_0_0_1.wav
# waves_yesno/1_1_0_1_1_1_1_0.wav
# waves_yesno/0_0_1_1_1_1_0_0.wav
# waves_yesno/1_1_0_0_1_1_1_0.wav
# waves_yesno/0_0_1_1_0_1_1_1.wav
# waves_yesno/1_1_0_1_0_1_1_0.wav
# waves_yesno/0_1_0_0_0_1_1_0.wav
# waves_yesno/0_0_0_1_0_0_0_1.wav
# waves_yesno/0_0_1_0_1_0_1_1.wav
# waves_yesno/0_0_1_0_0_0_1_0.wav
# waves_yesno/1_1_0_1_1_0_0_1.wav
# waves_yesno/0_1_1_1_0_1_0_1.wav
# waves_yesno/0_1_1_1_0_0_0_0.wav
# waves_yesno/README~
# waves_yesno/0_1_0_0_0_1_0_0.wav
# waves_yesno/1_0_0_0_0_0_0_1.wav
# waves_yesno/1_1_0_1_1_0_1_1.wav
# waves_yesno/1_1_0_0_0_0_0_1.wav
# waves_yesno/1_0_0_0_0_0_0_0.wav
# waves_yesno/0_1_1_1_1_0_1_0.wav
# waves_yesno/0_0_1_1_0_1_0_0.wav
# waves_yesno/1_1_1_0_0_0_0_1.wav
# waves_yesno/1_0_1_0_1_0_0_1.wav
# waves_yesno/0_1_0_0_1_0_1_1.wav
# waves_yesno/0_0_1_1_1_1_1_0.wav
# waves_yesno/1_1_0_0_0_1_1_1.wav
# waves_yesno/0_1_1_1_0_0_1_0.wav
# waves_yesno/1_1_0_1_0_1_0_0.wav
# waves_yesno/1_1_1_1_1_1_1_1.wav
# waves_yesno/0_0_1_0_1_0_0_1.wav
# waves_yesno/1_1_1_1_0_0_1_0.wav
# waves_yesno/0_0_1_1_1_0_0_1.wav
# waves_yesno/0_1_0_1_0_0_0_0.wav
# waves_yesno/1_1_1_1_1_0_0_0.wav
# waves_yesno/README
# waves_yesno/0_1_1_0_0_1_1_1.wav
# waves_yesno/0_0_1_0_0_1_1_0.wav
# waves_yesno/1_1_0_0_1_0_1_1.wav
# waves_yesno/1_1_1_0_0_1_0_1.wav
# waves_yesno/0_0_1_0_0_1_1_1.wav
# waves_yesno/0_0_1_1_0_0_0_1.wav
# waves_yesno/1_0_1_1_0_1_1_1.wav
# waves_yesno/1_1_1_0_1_0_1_0.wav
# waves_yesno/1_1_1_0_1_0_1_1.wav
# waves_yesno/0_1_0_0_1_0_1_0.wav
# waves_yesno/1_1_1_0_0_1_1_1.wav
# waves_yesno/0_1_1_0_0_1_1_0.wav
# waves_yesno/0_0_0_1_0_1_1_0.wav
# waves_yesno/1_1_1_1_1_1_0_0.wav
# waves_yesno/0_0_0_0_1_1_1_1.wav

# %%
# Загрузим один из файлов
wav, sr = librosa.load("waves_yesno/0_1_0_1_1_1_0_0.wav")
draw_waveform(wav, sr)
Audio(wav, rate=sr)
# Out:
#         <script>
#             if (!window.audioContext) {
#                 window.audioContext = new AudioContext();
#                 window.playAudio = function(audioChannels, sr) {
#                     const buffer = audioContext.createBuffer(audioChannels.length, audioChannels[0].length, sr);
#                     for (let [channel, data] of audioChannels.entries()) {
#                         buffer.copyToChannel(Float32Array.from(data), channel);
#                     }
#
#                     const source = audioContext.createBufferSource();
#                     source.buffer = buffer;
#                     source.connect(audioContext.destination);
#                     source.start();
#                 }
#             }
#         </script>
#         <button onclick="playAudio([[3.253789691370912e-05, 4.9797370593296364e-05, 5.9080764913233e-05, 5.755815436714329e-05, 4.8197831347351894e-05, 3.725743226823397e-05, 2.989661334140692e-05, 2.739247247518506e-05, 2.7772472094511613e-05, 2.8710512196994387e-05, 2.9900811568950303e-05, 3.3032330975402147e-05, 3.979186658398248e-05, 4.984783663530834e-05, 6.039821892045438e-05, 6.73795584589243e-05, 6.737544026691467e-05, 5.9292156947776675e-05, 4.532828097580932e-05, 3.080347232753411e-05, 2.224028139607981e-05, 2.3723281628917903e-05, 3.32728486682754e-05, 4.232093124301173e-05, 4.028347029816359e-05, 2.2424766939366236e-05, -4.5497608880396e-06, -2.4607148588984273e-05, -2.2440068278228864e-05, 5.0805242608475965e-06, 4.50335064670071e-05, 7.619315874762833e-05, 8.333707228302956e-05, 6.73158501740545e-05, 4.304281173972413e-05, 2.7262560251983814e-05, 2.6274281481164508e-05, 3.343568096170202e-05, 3.749435200006701e-05, 3.343550633871928e-05, 2.5996669137384742e-05, 2.34598082897719e-05, 2.8591190130100586e-05, 3.5870700230589136e-05, 3.7475332646863535e-05, 3.159266634611413e-05, 2.4394468709942885e-05, 2.3597231120220385e-05, 3.027162529178895e-05, 3.749830648303032e-05, 3.748301969608292e-05, 2.987917650898453e-05, 2.2519860067404807e-05, 2.3425072868121788e-05, 3.2162944989977404e-05, 3.976662992499769e-05, 3.78318945877254e-05, 2.7664103981805965e-05, 1.966260970220901e-05, 2.283931644342374e-05, 3.489814844215289e-05, 4.356998761068098e-05, 3.883662066073157e-05, 2.4069675419013947e-05, 1.4108561117609497e-05, 2.0864676116616465e-05, 4.012294448330067e-05, 5.3315554396249354e-05, 4.404847641126253e-05, 1.4274595741881058e-05, -1.5796482330188155e-05, -2.500100526958704e-05, -1.0018125067290384e-05, 1.2049971701344475e-05, 1.9867822629748844e-05, 7.462976554961642e-06, -1.1343580808897968e-05, -1.7470507373218425e-05, -5.489157956617419e-06, 1.162956323241815e-05, 1.6186810171348043e-05, 3.785612307183328e-06, -1.245205112354597e-05, -1.5552197510260157e-05, -2.2122267182567157e-06, 1.3722000403504353e-05, 1.5453144442290068e-05, 6.931997518222488e-07, -1.5540112144663e-05, -1.6009282262530178e-05, 8.053912097238936e-07, 1.8267985069542192e-05, 1.775386044755578e-05, -2.2219442143978085e-06, -2.304910412931349e-05, -2.2827833163319156e-05, 2.881783075281419e-06, 3.631631989264861e-05, 5.3426094382302836e-05, 4.5310502173379064e-05, 2.4997458240250126e-05, 1.3815554666507524e-05, 2.1162477423786186e-05, 3.714931881404482e-05, 4.43109092884697e-05, 3.5825894883600995e-05, 2.191191742895171e-05, 1.8468697817297652e-05, 2.9890101359342225e-05, 4.353984331828542e-05, 4.150759559706785e-05, 1.8043512682197616e-05, -1.4438197467825375e-05, -3.652020313893445e-05, -3.909394581569359e-05, -3.0137167414068244e-05, -2.4937478883657604e-05, -2.9948396331747063e-05, -3.633541928138584e-05, -2.938778925454244e-05, -4.312081728130579e-06, 2.7233052605879493e-05, 4.64458717033267e-05, 4.3878506403416395e-05, 2.7685131499310955e-05, 1.602811062184628e-05, 2.0741395928780548e-05, 3.706402640091255e-05, 4.827554585062899e-05, 4.054971941513941e-05, 1.4827699487796053e-05, -1.3928779480920639e-05, -2.8372354790917598e-05, -2.100559140671976e-05, 2.170948164348374e-06, 2.751852480287198e-05, 4.280998109607026e-05, 4.2668722016969696e-05, 2.851223325706087e-05, 5.6847184168873355e-06, -1.915197935886681e-05, -3.9833332266425714e-05, -5.2723677072208375e-05, -5.876419163541868e-05, -6.346723239403218e-05, -7.335680857067928e-05, -9.057414717972279e-05, -0.0001100169902201742, -0.00012221300858072937, -0.00012054133549099788, -0.00010736988042481244, -9.393945947522298e-05, -9.34146810323e-05, -0.00011170041398145258, -0.00014236186689231545, -0.00016928355034906417, -0.0001757958234520629, -0.0001550797460367903, -0.00011565032036742195, -7.789849041728303e-05, -6.235863838810474e-05, -7.58897076593712e-05, -0.00010515429312363267, -0.000124128331663087, -0.00011329326662234962, -7.780072337482125e-05, -4.908315895590931e-05, -6.437177 ...

# %% [markdown]
# Как можно услышать, в этом датасете произносятся какие-то два слова (yes/no на иврите). Каждый файл состоит из 8 произнесений. Метки слов указаны в названиях файлов.

# %%
# Построим спектрограмму загруженной вавки
stft = librosa.stft(wav)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(15,10))
librosa.display.specshow(stft_db, sr=sr, x_axis='time', y_axis='hz')

# %% [markdown]
# # Задание 0.1: Анализ спектрограммы (0.5 балла)
# 1. Посмотрите на спектрограмму и попробуйте найти признаки, по которым можно отличить произнесение "yes" от "no".
# 1. В каких частотах находится основная энергия этого речевого сигнала?

# %% [markdown]
# 1. В облости высоких частот, выше 2500, энергия сигнала "yes"(1) выше
# 2. 0-2000

# %% [markdown]
# # Задание 1: Мел-шкала (1 балл)
# Нарисовать спектрограму в [mel-шкале](https://en.wikipedia.org/wiki/Mel_scale).
# Использовать формулу, представленную Дугласом О'Шонесси.

# %%
def mel(spec):
    return 2595 * np.log(1 + spec/700)/np.log(2)
def hz(spec):
    return 700.0 * (10.0 ** (spec / 2595.0) - 1.0)

# %%
def test_mel():
    x = np.random.randint(100, size=(1000, 100))
    x_mel = mel(x)
    x_hz = hz(x_mel) #700.0 * (10.0 ** (x_mel / 2595.0) - 1.0)
    assert np.allclose(x, x_hz), "TEST Hertz -> Mel -> Hertz  failed. "

# %% [markdown]
# # Мел-фильтры
# Одними из наиболее популярных акустических признаков являются Filter Banks (fbanks).
# fbanks вычисляются применением нескольких (количество фильтров = количество fbanks) треугольных фильтров к мел-спектрограмме. Чтобы не делать два действия со спектрограммой, переход к мел-шкале и применение фильтров в мел-шкале можно заменить на перевод мел-фильтров в Герц-шкалу и применение их к Герц-спектрограмме.
#
#
#
# # Задание 2 (3 балла)
# Реализуйте функцию вычисления fbank.

# %%
def mel_filters(sr:int, n_fft:int, n_mels:int):
    # функция построения треугольных мел-фильтров в герц-шкале
    # sr - sample rate
    # n_fft - length of the FFT window 
    # n_mels - number of filters
    # return mel filters matrix. [n_mel, n_fft]
    fftfreqs = np.linspace(0, sr/2, int(n_fft//2)+1)
    mel_f = hz(np.linspace(mel(0), mel(sr/6.8), n_mels+2))
    
    fdiff = np.diff(mel_f)
    ramps = np.subtract.outer(mel_f, fftfreqs)

    weight = np.zeros((n_mels, int(n_fft//2+1)))

    for i in range(n_mels):
        lowwer = -ramps[i]/fdiff[i]
        upper = ramps[i+2]/fdiff[i+1]
        weight[i] = np.maximum(0, np.minimum(lowwer, upper)) 
    enorm = 2.0 / (mel_f[2 : n_mels + 2] - mel_f[:n_mels])
    weight *= enorm[:, np.newaxis]
    return weight

# %%
plt.plot(mel_filters(32, 46, 4).T);
# mel_filters(32, 46, 4)[-1].T

# %%
assert mel_filters(32, 46, 4).shape == (4, 24) and \
    mel_filters(65, 45, 5).shape == (5, 23), "Wrong shape"
assert np.allclose(mel_filters(16, 8, 4), librosa.filters.mel(16, 8, n_mels=4))
assert np.allclose(mel_filters(8600, 512, 40), librosa.filters.mel(8600, 512, n_mels=40))
print("All ok!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_27322/3767069382.py in <module>
#       1 assert mel_filters(32, 46, 4).shape == (4, 24) and \
#       2     mel_filters(65, 45, 5).shape == (5, 23), "Wrong shape"
# ----> 3 assert np.allclose(mel_filters(16, 8, 4), librosa.filters.mel(16, 8, n_mels=4))
#       4 assert np.allclose(mel_filters(8600, 512, 40), librosa.filters.mel(8600, 512, n_mels=40))
#       5 print("All ok!")
#
# AssertionError:

# %%
def get_fbanks(wav: np.ndarray, sr: int, window_ms=25, step_mc=10, n_fbanks=40):
    # wav - input signal
    # sr - sample rate
    # window_ms - window length in milliseconds
    # step_ms - stft step in milliseconds
    # n_fbanks - number of filters
    # return fbank matrix [n_fbanks, time]
    n_fft = window_ms * sr//1000
    hop_length = step_mc * sr//1000
    spec = librosa.stft(wav, 
                        n_fft=n_fft, 
                        hop_length=hop_length)
    spec = np.abs(spec)**1
    f_bank = librosa.filters.mel(sr, n_fft, n_mels=n_fbanks)
    res =  np.dot(f_bank, spec)
    return res

# %%
def test_fbank(wav, sr, window_ms=25, step_mc=10, n_fbanks=40):
    n_fft = window_ms * sr//1000
    hop_length = step_mc * sr//1000
    fbanks_lib = librosa.feature.melspectrogram(wav, sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_fbanks)
    fbanks = get_fbanks(wav, sr, window_ms=window_ms, step_mc=step_mc, n_fbanks=n_fbanks)
    
    if fbanks_lib.shape != fbanks.shape:
        print("TEST FAILED")
        print(f"Shape {fbanks_lib.shape} != {fbanks.shape}")
    if not np.allclose(fbanks_lib, fbanks):
        print("TEST FAILED")
        print(f"Average diff is {np.mean(np.abs(fbanks_lib - fbanks))}")
        return -1
    print("TEST PASSED")
    return 0
assert test_fbank(wav[:sr*1], sr) == 0, "1 sec wav test failed"
assert test_fbank(wav, sr) == 0 , "All wav test failed"
print("All ok!")
# Out:
# TEST FAILED
# Average diff is 0.0004812526749446988
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_3290/4156597732.py in <module>
#      14     print("TEST PASSED")
#      15     return 0
# ---> 16 assert test_fbank(wav[:sr*1], sr) == 0, "1 sec wav test failed"
#      17 assert test_fbank(wav, sr) == 0 , "All wav test failed"
#      18 print("All ok!")
#
# AssertionError: 1 sec wav test failed

# %%
fbanks = get_fbanks(wav, sr)
plt.figure(figsize=(5,5))
librosa.display.specshow(fbanks, sr=sr, x_axis='time')
plt.ylabel("Filter number")
plt.show()

# %%
fbanks = get_fbanks(wav, sr)
plt.figure(figsize=(5, 5))
librosa.display.specshow(fbanks, sr=sr, x_axis='time')
plt.ylabel("Filter number")
plt.show()

# %% [markdown]
# # Задание 4 (3 балла)
# Реализовать вычисление [mfcc](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum)

# %%
def get_mfcc(wav: np.ndarray, sr: int, window_ms=25, step_mc=10, n_mfcc=13):
      # wav - input signal
    # sr - sample rate
    # window_ms - window length in milliseconds
    # step_ms - stft step in milliseconds
    # n_mfcc - number of filters
    # return mfcc matrix [n_mfcc, time]
    n_fft = window_ms * sr//1000
    hop_length = step_mc * sr//1000
    fbanks_lib = librosa.feature.melspectrogram(wav, sr, n_fft=n_fft, hop_length=hop_length)
    fbanks_lib = librosa.power_to_db(fbanks_lib)

    
    return scipy.fftpack.dct(fbanks_lib, axis=0, type=2, norm='ortho')[:n_mfcc]

# %%
def test_mfcc(wav, sr, window_ms=25, step_mc=10, n_mfcc=13):
    n_fft = window_ms * sr//1000
    hop_length = step_mc * sr//1000
    mfcc_lib = librosa.feature.mfcc(wav, sr, n_fft=n_fft, hop_length=hop_length, n_mfcc=n_mfcc)
    mfcc = get_mfcc(wav, sr, window_ms=window_ms, step_mc=step_mc, n_mfcc=n_mfcc)
    
    if mfcc_lib.shape != mfcc.shape:
        print("TEST FAILED")
        print(f"Shape {mfcc_lib.shape} != {mfcc.shape}")
    if not np.allclose(mfcc_lib, mfcc):
        print("TEST FAILED")
        print(f"Average diff is {np.mean(np.abs(mfcc_lib - mfcc))}")
        return -1
    print("TEST PASSED")
    return 0
assert test_mfcc(wav[:sr*1], sr) == 0, "1 sec wav test failed"
assert test_mfcc(wav, sr) == 0 , "All wav test failed"
print("All ok!")
# Out:
# TEST PASSED
# TEST PASSED
# All ok!

# %%
mfcc = get_mfcc(wav, sr)
plt.figure(figsize=(15,10))
librosa.display.specshow(mfcc, sr=sr, x_axis='time')
plt.ylabel("Filter number")
plt.show()

# %% [markdown]
# # Классификация слов
# Построим простую систему, классифицирующую слова yes/no.

# %% [markdown]
# Загрузим весь датасет

# %%
def load_yn_dataset(directory):
    X, labels = [], []
    bad_files = set(["0_1_0_1_0_0_0_0"])
    for f in glob(directory +"/*.wav"):
        name = os.path.basename(f)[:-4]
        if name in bad_files:
            continue
        y = [int(l) for l in name.split("_")]
        x, _ = librosa.load(f)
        X.append(x)
        labels.append(y)
        
    return X, labels
        
X, Y = load_yn_dataset("waves_yesno/")

# %% [markdown]
# Отделим 20% для теста

# %%
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y,test_size=0.2, random_state=1)

# %% [markdown]
# # Задание *5 (1 балл)
# Voice Activity Detector (VAD) определяет, есть ли речь в текущем кадре.
# Реализуйте простой VAD. Настройте VAD, чтобы хорошо определялись границы слов.
#
# Подсказка:
# Можно отличать паузу от речи по энергии mfcc спектра( или части спектра). Чтобы предотвратить скачки на краях слов, воспользуйтесь сверткой со сглаживающим окном, например, Ханна.

# %%
# YOUR CODE HERE
train_mfcc = []
test_mfcc = []
for wav in X_train:
    mfcc = librosa.feature.mfcc(wav, 22050, n_mfcc=20)
    train_mfcc.append(mfcc)
for wav in X_test:
        mfcc = librosa.feature.mfcc(wav, 22050, n_mfcc=20)
        test_mfcc.append(mfcc)

# %%
train_mfcc = np.concatenate(train_mfcc, axis=1)

# %%
from joblib import dump, load
import sklearn.mixture

GMM = sklearn.mixture.GaussianMixture(2)
GMM.fit(train_mfcc)
dump(GMM, "gmm.joblib")

# %%
GMM = load("gmm.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27876/3755579049.py in <module>
# ----> 1 GMM = load("gmm.joblib")
#
# NameError: name 'load' is not defined

# %%
GMM.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27876/1677934473.py in <module>
# ----> 1 GMM.predict(X_train)
#
# NameError: name 'GMM' is not defined

# %%
def test_VAD(VA, Y, min_acc=0.95):
    def check_ali(ali, num_words):
        diff = ali[1:]  - ali[:-1]
        if diff.sum()!=0:
            print("VAD detected speech at the beginning (or end) of audio")
            return -1 
        if not (diff > 0).sum() == (diff > 0).sum() ==  num_words:
            return -2 
        return 0
    
    bad_i = []
    err =0
    for i, (ali, y) in enumerate(zip(VA, Y)):
        if check_ali(ali, len(y)) != 0:
            bad_i.append(i)
            err+=1
    acc = (len(Y) - err)/len(Y)
    print(f"Accuracy {acc}")
    if len(bad_i) >0:
        print(f"ids with error {bad_i}")
    assert acc >= min_acc , f"Accuracy must be >= {min_acc}"
    print("Test passed")

test_VAD(train_VA, Y_train)
test_VAD(test_VA, Y_test)
print("VAD ok!")
# Out:
# Accuracy 0.9787234042553191
# ids with error [0]
# Test passed
# VAD detected speech at the beginning (or end) of audio
# Accuracy 0.9166666666666666
# ids with error [0]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_3290/25968067.py in <module>
#      23
#      24 test_VAD(train_VA, Y_train)
# ---> 25 test_VAD(test_VA, Y_test)
#      26 print("VAD ok!")
#
# /tmp/ipykernel_3290/25968067.py in test_VAD(VA, Y, min_acc)
#      19     if len(bad_i) >0:
#      20         print(f"ids with error {bad_i}")
# ---> 21     assert acc >= min_acc , f"Accuracy must be >= {min_acc}"
#      22     print("Test passed")
#      23
#
# AssertionError: Accuracy must be >= 0.95

# %% [markdown]
# # Задание *6 (2 балла)
# Обучите классификатор, определяющий, какое слово было сказано. Используйте VAD для разбиения входных файлов на отдельные слова. Классификацию можно сделать, например, с помощью SVM по усредненным признаки выделеных VAD'ом слов. Или любым другим удобным для вас способом. Добейтесь точности больше 0.95
